# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv("probe_selection/gen_coords_cbc5b7f0.txt",sep="\t")
df.head()
# Out:
#   Variation ID        dbSNP Chromosome  Position REF Allele  \
# 0  rs397834473  rs397834473          1    985450          G
# 1    rs1061884    rs1061884          1   1660726          T
# 2   rs10797413   rs10797413          1   2036263          G
# 3    rs2840532    rs2840532          1   2327815          C
# 4   rs10909873   rs10909873          1   2998998          C
#
#   ALT Allele (IUPAC) Minor Allele Minor Allele Global Frequency      Contig  \
# 0                  W            A                      0.446486  GL000003.1
# 1                  C            C                      0.471845  GL000003.1
# 2                  A            G                      0.434904  GL000003.1
# 3                  T            C                      0.475839  GL000003.1
# 4                  R            C                      0.434904  GL000003.1
#
#    Contig Position    Band
# 0           464082  p36.33
# 1          1139358  p36.33
# 2          1514895  p36.33
# 3          1806447  p36.32
# ...

# %%
df["Variation ID"].to_clipboard(index=False)
# Out:
# /Users/nkrumm/.virtualenvs/data/lib/python3.7/site-packages/pandas/io/clipboards.py:117: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   obj.to_csv(buf, sep=sep, encoding="utf-8", **kwargs)

# %%
# annotated with snp-nexus https://www.snp-nexus.org/v4/results/d3e01ee3/

# %%
pop_df = pd.read_csv("probe_selection/1KGen_d3e01ee3.txt", sep="\t")

# %%
for i in ['AFR Frequency', 'AMR Frequency', 'EAS Frequency', 'EUR Frequency', 'SAS Frequency']:
    pop_df[i] = pd.to_numeric(pop_df[i], errors='coerce')

# %%
pop_df["EUR Frequency"].hist(bins=100)

# %%
pop_df["AFR Frequency"].hist(bins=100)

# %%
import matplotlib.pyplot as plt

# %%
# roughly checking population stratification -- looks OK
plt.scatter(pop_df["EUR Frequency"], pop_df["AFR Frequency"], s=3, alpha=0.1)
